# %% [markdown]
# # Description

# %% [markdown]
# The purpose of the notebook is to create a standardized way of analyzing datasets with basic machine learning techniques.
#
# All imports are done under imports.
#
# The class DataAnalysis is created below with built-in functions for quick analyzing.
#
# For more comprehensive data analysis, some of the functions can be copied, though one is best of preparing another notebook with more extensive cleaning, feature engineering, hyperparameter tuning, more models and deeper models.

# %% [markdown]
# _________________________________

# %% [markdown]
# # IMPORTS

# %%
import warnings
warnings.filterwarnings('ignore')

# Data wrangling
import pandas as pd
import numpy as np
import re

#Visualization 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Setting style
sns.set_context('talk')
sns.set_style('ticks')
sns.set_palette('dark')

# Regression
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.metrics import mean_squared_error

# %%
# Root mean squared error for GridSearchCrossValidate for later
def rmse(ytrue, ypredicted):
        return np.sqrt(mean_squared_error(ytrue, ypredicted))

# %% [markdown]
# # CLASS: DataAnalysis

# %%
class DataAnalysis:
    '''
    The DataAnalysis class is used for objectives such as: 'Time Series', 'Classification' and 'Regression.' 
    '''
    def __init__(self, df, y, objective):
        self.df = df
        
        
        # Define objective 
        self.objective = objective
        print('The objective of the analysis is: ', objective)
        print('------------------------------------------------------------------------------')
        
        if self.objective.lower() == 'regression':
            print('-----------------------------------------------------------------------------')
            print('The first 5 rows of the dataframe')
            display(df.head())
            print('-----------------------------------------------------------------------------')
            print('Dataframe info\n')
            print(df.info())
            print('-----------------------------------------------------------------------------')
            print('Count, mean, standard deviation and five-number summary')
            display(df.describe())
            print('-----------------------------------------------------------------------------')
            print('Correlation matrix  Remember to remove comment')
            sns.pairplot(self.df)
            plt.show()
            print('-----------------------------------------------------------------------------')

            # X and y
            self.X = self.df.drop(y, axis = 1)
            self.y = self.df[y]

            # Pred dict and regressors dict for later
            self.predictions = dict()
            self.regressors_dict = dict()
        
    #------------------------------------------------------------------------------------------------------------------------
    # CREATE REGRESSION MODEL
    # Explain it
    def explan_modelling(self):
        print('Step 1: Train-test split')
        print('Data dependent: Scale (Here StandardScaler is used)')
        print('Step 2: Create polynomial features')
        print('Step 3: Regression models')
        print('Step 4: See performance')

    # First, create train-test set 
    def train_test_split(self, test_size):
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(self.X, self.y, test_size = test_size)
    
    # Data dependent, scaling
    def scale_standard(self):
        ss = StandardScaler()
        self.X_train_ss = ss.fit_transform(self.X_train)
        self.X_test_ss = ss.fit_transform(self.X_test)
        
    # Second, create polynomial features for non-linear features
    # Creating object of the polynomial features class from sklearn
    def create_poly_features(self, degrees):
        # Instantiating 
        pf = PolynomialFeatures(degree = degrees)

        # Create features 
        self.X_poly_train = pf.fit_transform(self.X_train_ss)
        self.X_poly_test = pf.fit_transform(self.X_test_ss)
            
    
    def create_regressors_and_predict(self, linear_regression = True, ridge_regression = True, lasso_regression = True,
                                     alpha_ridge = 14000, max_iter=100000, alpha_lasso = 1e-06):
        '''
        Specify if either linear, ridge or lasso regression is not wished.
        '''
        
        
        if linear_regression == True:
            # LINEAR REGRESSION
            linear = LinearRegression()
            # Fitting to linear regression 
            self.linear = linear.fit(self.X_train, self.y_train)
            # Predicting 
            self.y_pred_linear = self.linear.predict(self.X_test)
            print('The fitted linear regressions model is assigned to self.linear, and predictions are self.y_pred_linear')
            # For later
            self.predictions['linear'] = self.y_pred_linear
            self.regressors_dict['linear'] = self.linear
    
        if ridge_regression == True:
            # RIDGE REGRESSION
            ridge = Ridge(alpha=alpha_ridge, max_iter=max_iter)
            # Fitting to ridge regression
            self.ridge = ridge.fit(self.X_train, self.y_train)
            # Predicting 
            self. y_pred_ridge = self.ridge.predict(self.X_test)
            print('The fitted ridge regressions model is assigned to self.ridge, and predictions are self.y_pred_ridge')
            # For later
            self.predictions['ridge'] = self.y_pred_ridge
            self.regressors_dict['ridge'] = self.ridge

        if lasso_regression == True:
            # LASSO REGRESSION 
            lasso = Lasso(alpha=alpha_lasso)
            # Fitting to lasso regression
            self.lasso = lasso.fit(self.X_train, self.y_train)
            # Predicting 
            self.y_pred_lasso = self.lasso.predict(self.X_test)
            print('The fitted lasso regressions model is assigned to self.lasso, and predictions are self.y_pred_lasso')
            # For later
            self.predictions['lasso'] = self.y_pred_lasso
            self.regressors_dict['lasso'] = self.lasso
            
    def create_poly_regressors_and_predict(self, linear_regression_poly = True, ridge_regression_poly = True,
                                           lasso_regression_poly = True, 
                                           max_iter=10000000, find_parameters_automatically = True):
        # SET TO FIND PARAMETERS AUTOMATICALLY 
        '''
        Specify if either linear, ridge or lasso regression is not wished.
        '''
        if linear_regression_poly == True:
            # LINEAR REGRESSION with polynomial features
            linear_poly = LinearRegression()
            # Fitting to linear regression
            self.linear_poly = linear_poly.fit(self.X_poly_train, self.y_train)
            # Predicting 
            self.y_pred_linear_poly = self.linear_poly.predict(self.X_poly_test)
            print('The fitted linear regressions model is assigned to self.linear_poly, and predictions are self.y_pred_linear_poly')
            # Later
            self.predictions['linear poly'] = self.y_pred_linear_poly
            self.regressors_dict['linear poly'] = self.linear_poly
    
        if ridge_regression_poly == True:
            if find_parameters_automatically == True:
                # Alphas to try
                alphas = [0.005, 0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 80, 100, 200, 5000, 10000, 13000, 14000, 15000, 16000, 17500, 20000] 
                # Create ridgecv object
                ridgeCV = RidgeCV(alphas=alphas).fit(self.X_poly_train, self.y_train)
                # Use the rmse function to calculate
                ridgeCV_rmse = rmse(self.y_test, ridgeCV.predict(self.X_poly_test))
                self.alpha_ridge_poly = ridgeCV.alpha_
                
                
            # RIDGE REGRESSION with polynomial features
            self.ridge_poly = Ridge(alpha=self.alpha_ridge_poly, max_iter=max_iter)
            # Fitting to ridge regression
            self.ridge_poly = self.ridge_poly.fit(self.X_poly_train, self.y_train)
            # Predicting 
            self.y_pred_ridge_poly = self.ridge_poly.predict(self.X_poly_test)
            print('The fitted ridge regressions model is assigned to self.ridge_poly, and predictions are self.y_pred_ridge_poly')
            # Later
            self.predictions['ridge poly'] = self.y_pred_ridge_poly
            self.regressors_dict['ridge poly'] = self.ridge_poly
            
            
        if lasso_regression_poly == True:
            if find_parameters_automatically == True:
                # Define alphas to try out 
                alphas2 = np.array([1e-6, 5e-5, 1e-5, 5e-5, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1])
                # Create lassocv object
                lassoCV = LassoCV(alphas=alphas2).fit(self.X_poly_train, self.y_train)
                # Use the rmse function to calculate
                lassoCV_rmse = rmse(self.y_test, lassoCV.predict(self.X_poly_test))
                self.alpha_lasso_poly = lassoCV.alpha_
                
                
            # LASSO REGRESSION with polynomial features
            lasso_poly = Lasso(alpha=self.alpha_lasso_poly)
            # Fitting to lasso regression
            self.lasso_poly = lasso_poly.fit(self.X_poly_train, self.y_train)
            # Predicting 
            self.y_pred_lasso_poly = self.lasso_poly.predict(self.X_poly_test)
            print('The fitted lasso regressions model is assigned to self.lasso_poly, and predictions are self.y_pred_lasso_poly')
            # Later 
            self.predictions['lasso poly'] = self.y_pred_lasso_poly
            self.regressors_dict['lasso poly'] = self.lasso_poly
        
        
    def see_performance(self):
        # R2 scores 
        for regressor in self.predictions.keys():
            print(f'R2 score for {regressor}:', round(r2_score(self.y_test, self.predictions[regressor]),6))
        
        # Plotting
        fig, axes = plt.subplots(len(self.predictions.keys())+1,1, figsize = (15,len(self.predictions.keys())*10))
        axes[0].scatter(self.y_test, self.y_test, label = 'Test set')
        axes[0].set_title('Test set')
        axes[0].legend(loc='upper left')
        
            # Look at regressors 
        for i, regressor in enumerate(self.predictions.keys()):
            r2 = round(r2_score(self.y_test, self.predictions[regressor]),6)
            axes[i+1].scatter(self.y_test, self.predictions[regressor], label=regressor+' R2 score: '+str(r2))
            axes[i+1].set_title(regressor)
            axes[i+1].legend(loc='upper left')
    
    def check_coefficients(self):
        for regressor in self.regressors_dict.keys():
            #print(f'Coefficients for {regressor}:', self.regressors_dict[regressor].coef_.ravel())
            
            #Plot
            print(f'Coefficients for {regressor}')
            rang = np.arange(len(self.regressors_dict[regressor].coef_.ravel()))
            plt.figure(figsize=(15,3))
            plt.bar(rang, self.regressors_dict[regressor].coef_.ravel())
            plt.show()
    #------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 1. DATA AND EDA SETTING PARAMETERS AND INITIALIZING CLASS

# %%
df = pd.read_excel('data/Concrete_Data.xls')

# For ease of working with
# Renaming
for column in df.columns:
    regex = r"[a-zA-Z ]+"
    new_name = re.findall(regex, column)[0]
    df = df.rename(columns={column:new_name})
    
# Set X and y
y = 'Concrete compressive strength'

# %%
model = DataAnalysis(df, y, 'Classification')
# Out:
# The objective of the analysis is:  Classification
# ------------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# The first 5 rows of the dataframe
#    Cement   Blast Furnace Slag   Fly Ash   Water    Superplasticizer   \
# 0    540.0                  0.0       0.0    162.0                2.5
# 1    540.0                  0.0       0.0    162.0                2.5
# 2    332.5                142.5       0.0    228.0                0.0
# 3    332.5                142.5       0.0    228.0                0.0
# 4    198.6                132.4       0.0    192.0                0.0
#
#    Coarse Aggregate    Fine Aggregate   Age   Concrete compressive strength
# 0              1040.0            676.0    28                      79.986111
# 1              1055.0            676.0    28                      61.887366
# 2               932.0            594.0   270                      40.269535
# 3               932.0            594.0   365                      41.052780
# 4               978.4            825.5   360                      44.296075
# -----------------------------------------------------------------------------
# Dataframe info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Cement                         1030 non-null   float64
#  1   Blast Furnace Slag             1030 non-null   float64
#  2   Fly Ash                        1030 non-null   float64
#  3   Water                          1030 non-null   float64
#  4   Superplasticizer               1030 non-null   float64
#  5   Coarse Aggregate               1030 non-null   float64
#  6   Fine Aggregate                 1030 non-null   float64
#  7   Age                            1030 non-null   int64
#  8   Concrete compressive strength  1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB
# None
# -----------------------------------------------------------------------------
# Count, mean, standard deviation and five-number summary
#            Cement   Blast Furnace Slag      Fly Ash       Water    \
# count  1030.000000          1030.000000  1030.000000  1030.000000
# mean    281.165631            73.895485    54.187136   181.566359
# std     104.507142            86.279104    63.996469    21.355567
# min     102.000000             0.000000     0.000000   121.750000
# 25%     192.375000             0.000000     0.000000   164.900000
# 50%     272.900000            22.000000     0.000000   185.000000
# 75%     350.000000           142.950000   118.270000   192.000000
# max     540.000000           359.400000   200.100000   247.000000
#
#        Superplasticizer   Coarse Aggregate    Fine Aggregate          Age   \
# count        1030.000000         1030.000000      1030.000000  1030.000000
# mean            6.203112          972.918592       773.578883    45.662136
# std             5.973492           77.753818        80.175427    63.169912
# min             0.000000          801.000000       594.000000     1.000000
# 25%             0.000000          932.000000       730.950000     7.000000
# 50%             6.350000          968.000000       779.510000    28.000000
# 75%            10.160000         1029.400000       824.000000    56.000000
# max            32.200000         1145.000000       992.600000   365.000000
#
#        Concrete compressive strength
# count                    1030.000000
# mean                       35.817836
# std                        16.705679
# min                         2.331808
# 25%                        23.707115
# 50%                        34.442774
# 75%                        46.136287
# max                        82.599225
# -----------------------------------------------------------------------------
# Correlation matrix  Remember to remove comment
# -----------------------------------------------------------------------------

# %% [markdown]
# # 2. DATA ENGINEERING

# %% [markdown]
# ### Train-test split

# %%
# Train test split
model.train_test_split(0.3)

# %% [markdown]
# ### Scale (see the big difference from 'Coarse Aggregate' to Superplasticizer'

# %%
# Scale
model.scale_standard()

# %% [markdown]
# ### Poly features

# %%
model.create_poly_features(degrees = 2)

# %% [markdown]
# # 3. MODEL

# %% [markdown]
# ### Regressors

# %%
model.create_regressors_and_predict()
# Out:
# The fitted linear regressions model is assigned to self.linear, and predictions are self.y_pred_linear
# The fitted ridge regressions model is assigned to self.ridge, and predictions are self.y_pred_ridge
# The fitted lasso regressions model is assigned to self.lasso, and predictions are self.y_pred_lasso

# %%
model.create_poly_regressors_and_predict()
# Out:
# The fitted linear regressions model is assigned to self.linear_poly, and predictions are self.y_pred_linear_poly
# The fitted ridge regressions model is assigned to self.ridge_poly, and predictions are self.y_pred_ridge_poly
# The fitted lasso regressions model is assigned to self.lasso_poly, and predictions are self.y_pred_lasso_poly

# %% [markdown]
# ### Performance

# %%
model.predictions.keys()
# Out:
# dict_keys(['linear', 'ridge', 'lasso', 'linear poly', 'ridge poly', 'lasso poly'])

# %%
model.see_performance()
# Out:
# R2 score for linear: 0.571724
# R2 score for ridge: 0.577488
# R2 score for lasso: 0.571724
# R2 score for linear poly: 0.769765
# R2 score for ridge poly: 0.770464
# R2 score for lasso poly: 0.771926

# %%
# See coefficients
model.check_coefficients()
# Out:
# Coefficients for linear
# Coefficients for ridge
# Coefficients for lasso
# Coefficients for linear poly
# Coefficients for ridge poly
# Coefficients for lasso poly

# %% [markdown]
# __________________________________________

# %% [markdown]
# # ANN model

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import tensorflow as tf
tf.__version__

# Initializing the ANN
ann = tf.keras.models.Sequential()

# Adding the input layer and the first hidden layer
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# Adding the second hidden layer
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# Adding the output layer
ann.add(tf.keras.layers.Dense(units=1))

# %%
# Compiling the ANN
ann.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['accuracy'])

# %%
# Training the ANN on the Training set
ann.fit(model.X_train.values, model.y_train.values, batch_size = 32, epochs = 1000)
# Out:
# Train on 721 samples
# Epoch 1/1000
# 721/721 [==============================] - 0s 386us/sample - loss: 248654.5890 - accuracy: 0.0000e+00
# Epoch 2/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 44883.5977 - accuracy: 0.0000e+00
# Epoch 3/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 6458.5517 - accuracy: 0.0000e+00
# Epoch 4/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 5194.4555 - accuracy: 0.0000e+00
# Epoch 5/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 4945.8009 - accuracy: 0.0000e+00
# Epoch 6/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 4828.5773 - accuracy: 0.0000e+00
# Epoch 7/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 4702.2722 - accuracy: 0.0000e+00
# Epoch 8/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 4575.8827 - accuracy: 0.0000e+00
# Epoch 9/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 4444.1784 - accuracy: 0.0000e+00
# Epoch 10/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 4328.7325 - accuracy: 0.0000e+00
# Epoch 11/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 4199.2678 - accuracy: 0.0000e+00
# Epoch 12/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 4079.7807 - accuracy: 0.0000e+00
# Epoch 13/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 3962.1671 - accuracy: 0.0000e+00
# Epoch 14/1000
# 721/721 [==============================] - 0s 58us/sample - loss: 3808.3099 - accuracy: 0.0000e+00
# Epoch 15/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 3690.8614 - accuracy: 0.0000e+00
# Epoch 16/1000
# 721/721 [==============================] - 0s 85us/sample - loss: 3573.1210 - accuracy: 0.0000e+00
# Epoch 17/1000
# 721/721 [==============================] - 0s 60us/sample - loss: 3457.0428 - accuracy: 0.0000e+00
# Epoch 18/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 3349.7924 - accuracy: 0.0000e+00
# Epoch 19/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 3231.0960 - accuracy: 0.0000e+00
# Epoch 20/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 3117.8998 - accuracy: 0.0000e+00
# Epoch 21/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 3021.3980 - accuracy: 0.0000e+00
# Epoch 22/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 2914.0760 - accuracy: 0.0000e+00
# Epoch 23/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 2829.4132 - accuracy: 0.0000e+00
# Epoch 24/1000
# 721/721 [==============================] - 0s 69us/sample - loss: 2728.7321 - accuracy: 0.0000e+00
# Epoch 25/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 2635.1304 - accuracy: 0.0000e+00
# Epoch 26/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 2546.6791 - accuracy: 0.0000e+00
# Epoch 27/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 2462.9472 - accuracy: 0.0000e+00
# Epoch 28/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 2379.0466 - accuracy: 0.0000e+00
# Epoch 29/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 2311.8313 - accuracy: 0.0000e+00
# Epoch 30/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 2230.6859 - accuracy: 0.0000e+00
# Epoch 31/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 2153.4343 - accuracy: 0.0000e+00
# Epoch 32/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 2080.0880 - accuracy: 0.0000e+00
# Epoch 33/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 2033.2174 - accuracy: 0.0000e+00
# Epoch 34/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 1959.8622 - accuracy: 0.0000e+00
# Epoch 35/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 1877.4798 - accuracy: 0.0000e+00
# Epoch 36/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 1820.6657 - accuracy: 0.0000e+00
# Epoch 37/1000
# 721/721 [==============================] - 0s 58us/sample - loss: 1761.2736 - accuracy: 0.0000e+00
# Epoch 38/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 1705.0931 - accuracy: 0.0000e+00
# Epoch 39/1000
# 721/721 [==============================] - 0s 64us/sample - loss: 1646.0265 - accuracy: 0.0000e+00
# Epoch 40/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 1600.9310 - accuracy: 0.0000e+00
# Epoch 41/1000
# 721/721 [==============================] - 0s 60us/sample - loss: 1548.3177 - accuracy: 0.0000e+00
# Epoch 42/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 1487.6561 - accuracy: 0.0000e+00
# Epoch 43/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 1441.7227 - accuracy: 0.0000e+00
# Epoch 44/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 1394.7462 - accuracy: 0.0000e+00
# Epoch 45/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 1350.2558 - accuracy: 0.0000e+00
# Epoch 46/1000
# 721/721 [==============================] - 0s 64us/sample - loss: 1310.8726 - accuracy: 0.0000e+00
# Epoch 47/1000
# 721/721 [==============================] - 0s 61us/sample - loss: 1276.7693 - accuracy: 0.0000e+00
# Epoch 48/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 1226.3971 - accuracy: 0.0000e+00
# Epoch 49/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 1186.2036 - accuracy: 0.0000e+00
# Epoch 50/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 1147.7162 - accuracy: 0.0000e+00
# Epoch 51/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 1109.5192 - accuracy: 0.0000e+00
# Epoch 52/1000
# 721/721 [==============================] - 0s 62us/sample - loss: 1074.0735 - accuracy: 0.0000e+00
# Epoch 53/1000
# 721/721 [==============================] - 0s 60us/sample - loss: 1042.3105 - accuracy: 0.0000e+00
# Epoch 54/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 1007.1862 - accuracy: 0.0000e+00
# Epoch 55/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 973.2414 - accuracy: 0.0000e+00
# Epoch 56/1000
# 721/721 [==============================] - 0s 60us/sample - loss: 944.3456 - accuracy: 0.0000e+00
# Epoch 57/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 915.4079 - accuracy: 0.0000e+00
# Epoch 58/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 885.1115 - accuracy: 0.0000e+00
# Epoch 59/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 863.7978 - accuracy: 0.0000e+00
# Epoch 60/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 826.1054 - accuracy: 0.0000e+00
# Epoch 61/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 805.1536 - accuracy: 0.0000e+00
# Epoch 62/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 777.3980 - accuracy: 0.0000e+00
# Epoch 63/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 757.5452 - accuracy: 0.0000e+00
# Epoch 64/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 729.3511 - accuracy: 0.0000e+00
# Epoch 65/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 709.6673 - accuracy: 0.0000e+00
# Epoch 66/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 685.1259 - accuracy: 0.0000e+00
# Epoch 67/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 664.8458 - accuracy: 0.0000e+00
# Epoch 68/1000
# 721/721 [==============================] - 0s 67us/sample - loss: 642.9939 - accuracy: 0.0000e+00
# Epoch 69/1000
# 721/721 [==============================] - 0s 78us/sample - loss: 625.4624 - accuracy: 0.0000e+00
# Epoch 70/1000
# 721/721 [==============================] - 0s 60us/sample - loss: 602.1298 - accuracy: 0.0000e+00
# Epoch 71/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 586.7103 - accuracy: 0.0000e+00
# Epoch 72/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 567.9476 - accuracy: 0.0000e+00
# Epoch 73/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 552.6018 - accuracy: 0.0000e+00
# Epoch 74/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 534.4762 - accuracy: 0.0000e+00
# Epoch 75/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 517.6090 - accuracy: 0.0000e+00
# Epoch 76/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 499.6222 - accuracy: 0.0000e+00
# Epoch 77/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 489.1805 - accuracy: 0.0000e+00
# Epoch 78/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 471.0536 - accuracy: 0.0000e+00
# Epoch 79/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 461.0822 - accuracy: 0.0000e+00
# Epoch 80/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 443.7782 - accuracy: 0.0000e+00
# Epoch 81/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 430.3606 - accuracy: 0.0000e+00
# Epoch 82/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 418.6087 - accuracy: 0.0000e+00
# Epoch 83/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 410.5301 - accuracy: 0.0000e+00
# Epoch 84/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 394.2592 - accuracy: 0.0000e+00
# Epoch 85/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 383.7320 - accuracy: 0.0000e+00
# Epoch 86/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 370.4249 - accuracy: 0.0000e+00
# Epoch 87/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 360.4804 - accuracy: 0.0000e+00
# Epoch 88/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 348.7643 - accuracy: 0.0000e+00
# Epoch 89/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 341.5912 - accuracy: 0.0000e+00
# Epoch 90/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 329.3977 - accuracy: 0.0000e+00
# Epoch 91/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 320.5844 - accuracy: 0.0000e+00
# Epoch 92/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 313.0374 - accuracy: 0.0000e+00
# Epoch 93/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 307.6590 - accuracy: 0.0000e+00
# Epoch 94/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 297.7593 - accuracy: 0.0000e+00
# Epoch 95/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 288.7376 - accuracy: 0.0000e+00
# Epoch 96/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 279.9447 - accuracy: 0.0000e+00
# Epoch 97/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 272.8180 - accuracy: 0.0000e+00
# Epoch 98/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 264.1508 - accuracy: 0.0000e+00
# Epoch 99/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 257.9578 - accuracy: 0.0000e+00
# Epoch 100/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 251.7686 - accuracy: 0.0000e+00
# Epoch 101/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 244.1509 - accuracy: 0.0000e+00
# Epoch 102/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 239.4944 - accuracy: 0.0000e+00
# Epoch 103/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 234.1696 - accuracy: 0.0000e+00
# Epoch 104/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 227.0892 - accuracy: 0.0000e+00
# Epoch 105/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 222.2297 - accuracy: 0.0000e+00
# Epoch 106/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 215.4967 - accuracy: 0.0000e+00
# Epoch 107/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 210.8309 - accuracy: 0.0000e+00
# Epoch 108/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 205.2109 - accuracy: 0.0000e+00
# Epoch 109/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 202.1003 - accuracy: 0.0000e+00
# Epoch 110/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 196.7540 - accuracy: 0.0000e+00
# Epoch 111/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 194.5875 - accuracy: 0.0000e+00
# Epoch 112/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 189.6700 - accuracy: 0.0000e+00
# Epoch 113/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 184.6304 - accuracy: 0.0000e+00
# Epoch 114/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 179.6617 - accuracy: 0.0000e+00
# Epoch 115/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 177.2963 - accuracy: 0.0000e+00
# Epoch 116/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 176.2841 - accuracy: 0.0000e+00
# Epoch 117/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 174.8069 - accuracy: 0.0000e+00
# Epoch 118/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 167.5670 - accuracy: 0.0000e+00
# Epoch 119/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 163.2749 - accuracy: 0.0000e+00
# Epoch 120/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 160.1381 - accuracy: 0.0000e+00
# Epoch 121/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 156.8547 - accuracy: 0.0000e+00
# Epoch 122/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 153.6832 - accuracy: 0.0000e+00
# Epoch 123/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 153.8117 - accuracy: 0.0000e+00
# Epoch 124/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 149.1886 - accuracy: 0.0000e+00
# Epoch 125/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 146.1437 - accuracy: 0.0000e+00
# Epoch 126/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 145.7717 - accuracy: 0.0000e+00
# Epoch 127/1000
# 721/721 [==============================] - 0s 62us/sample - loss: 141.9760 - accuracy: 0.0000e+00
# Epoch 128/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 139.6530 - accuracy: 0.0000e+00
# Epoch 129/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 137.7087 - accuracy: 0.0000e+00
# Epoch 130/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 136.9481 - accuracy: 0.0000e+00
# Epoch 131/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 134.4608 - accuracy: 0.0000e+00
# Epoch 132/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 134.3607 - accuracy: 0.0000e+00
# Epoch 133/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 131.4167 - accuracy: 0.0000e+00
# Epoch 134/1000
# 721/721 [==============================] - 0s 60us/sample - loss: 129.2115 - accuracy: 0.0000e+00
# Epoch 135/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 127.1300 - accuracy: 0.0000e+00
# Epoch 136/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 126.8641 - accuracy: 0.0000e+00
# Epoch 137/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 124.5952 - accuracy: 0.0000e+00
# Epoch 138/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 122.8331 - accuracy: 0.0000e+00
# Epoch 139/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 124.0874 - accuracy: 0.0000e+00
# Epoch 140/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 120.3424 - accuracy: 0.0000e+00
# Epoch 141/1000
# 721/721 [==============================] - 0s 62us/sample - loss: 121.1634 - accuracy: 0.0000e+00
# Epoch 142/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 120.6938 - accuracy: 0.0000e+00
# Epoch 143/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 118.7522 - accuracy: 0.0000e+00
# Epoch 144/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 116.1209 - accuracy: 0.0000e+00
# Epoch 145/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 114.1815 - accuracy: 0.0000e+00
# Epoch 146/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 119.3853 - accuracy: 0.0000e+00
# Epoch 147/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 113.6969 - accuracy: 0.0000e+00
# Epoch 148/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 113.4898 - accuracy: 0.0000e+00
# Epoch 149/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 111.5727 - accuracy: 0.0000e+00
# Epoch 150/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 112.4398 - accuracy: 0.0000e+00
# Epoch 151/1000
# 721/721 [==============================] - 0s 78us/sample - loss: 112.2788 - accuracy: 0.0000e+00
# Epoch 152/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 112.4253 - accuracy: 0.0000e+00
# Epoch 153/1000
# 721/721 [==============================] - 0s 62us/sample - loss: 111.3117 - accuracy: 0.0000e+00
# Epoch 154/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 111.5635 - accuracy: 0.0000e+00
# Epoch 155/1000
# 721/721 [==============================] - 0s 62us/sample - loss: 108.9380 - accuracy: 0.0000e+00
# Epoch 156/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 108.2381 - accuracy: 0.0000e+00
# Epoch 157/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 111.8240 - accuracy: 0.0000e+00
# Epoch 158/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 106.4643 - accuracy: 0.0000e+00
# Epoch 159/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 108.3989 - accuracy: 0.0000e+00
# Epoch 160/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 106.0889 - accuracy: 0.0000e+00
# Epoch 161/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 104.6573 - accuracy: 0.0000e+00
# Epoch 162/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 104.6868 - accuracy: 0.0000e+00
# Epoch 163/1000
# 721/721 [==============================] - 0s 60us/sample - loss: 104.7077 - accuracy: 0.0000e+00
# Epoch 164/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 104.0615 - accuracy: 0.0000e+00
# Epoch 165/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 104.7308 - accuracy: 0.0000e+00
# Epoch 166/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 102.7979 - accuracy: 0.0000e+00
# Epoch 167/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 104.6584 - accuracy: 0.0000e+00
# Epoch 168/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 106.6085 - accuracy: 0.0000e+00
# Epoch 169/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 106.0122 - accuracy: 0.0000e+00
# Epoch 170/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 104.9983 - accuracy: 0.0000e+00
# Epoch 171/1000
# 721/721 [==============================] - 0s 72us/sample - loss: 105.4299 - accuracy: 0.0000e+00
# Epoch 172/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 102.4055 - accuracy: 0.0000e+00
# Epoch 173/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 101.3279 - accuracy: 0.0000e+00
# Epoch 174/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 101.2237 - accuracy: 0.0000e+00
# Epoch 175/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 100.6635 - accuracy: 0.0000e+00
# Epoch 176/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 101.4259 - accuracy: 0.0000e+00
# Epoch 177/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 101.6786 - accuracy: 0.0000e+00
# Epoch 178/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 102.1834 - accuracy: 0.0000e+00
# Epoch 179/1000
# 721/721 [==============================] - 0s 65us/sample - loss: 100.7810 - accuracy: 0.0000e+00
# Epoch 180/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 102.0366 - accuracy: 0.0000e+00
# Epoch 181/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 101.8116 - accuracy: 0.0000e+00
# Epoch 182/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 101.4025 - accuracy: 0.0000e+00
# Epoch 183/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 101.7268 - accuracy: 0.0000e+00
# Epoch 184/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 99.8432 - accuracy: 0.0000e+00
# Epoch 185/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 101.5249 - accuracy: 0.0000e+00
# Epoch 186/1000
# 721/721 [==============================] - 0s 61us/sample - loss: 99.4896 - accuracy: 0.0000e+00
# Epoch 187/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 100.1511 - accuracy: 0.0000e+00
# Epoch 188/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 99.3490 - accuracy: 0.0000e+00
# Epoch 189/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 98.1688 - accuracy: 0.0000e+00
# Epoch 190/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 99.5371 - accuracy: 0.0000e+00
# Epoch 191/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 98.3133 - accuracy: 0.0000e+00
# Epoch 192/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 99.8661 - accuracy: 0.0000e+00
# Epoch 193/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 98.7620 - accuracy: 0.0000e+00
# Epoch 194/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 96.6577 - accuracy: 0.0000e+00
# Epoch 195/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 98.2703 - accuracy: 0.0000e+00
# Epoch 196/1000
# 721/721 [==============================] - 0s 61us/sample - loss: 100.1619 - accuracy: 0.0000e+00
# Epoch 197/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 100.7525 - accuracy: 0.0000e+00
# Epoch 198/1000
# 721/721 [==============================] - 0s 58us/sample - loss: 103.5094 - accuracy: 0.0000e+00
# Epoch 199/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 97.5737 - accuracy: 0.0000e+00
# Epoch 200/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 96.2606 - accuracy: 0.0000e+00
# Epoch 201/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 99.6130 - accuracy: 0.0000e+00
# Epoch 202/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 97.0278 - accuracy: 0.0000e+00
# Epoch 203/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 95.7945 - accuracy: 0.0000e+00
# Epoch 204/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 95.6761 - accuracy: 0.0000e+00
# Epoch 205/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 96.0657 - accuracy: 0.0000e+00
# Epoch 206/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 97.2002 - accuracy: 0.0000e+00
# Epoch 207/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 95.1584 - accuracy: 0.0000e+00
# Epoch 208/1000
# 721/721 [==============================] - 0s 62us/sample - loss: 95.3198 - accuracy: 0.0000e+00
# Epoch 209/1000
# 721/721 [==============================] - 0s 74us/sample - loss: 94.8790 - accuracy: 0.0000e+00
# Epoch 210/1000
# 721/721 [==============================] - 0s 65us/sample - loss: 96.9969 - accuracy: 0.0000e+00
# Epoch 211/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 94.9521 - accuracy: 0.0000e+00
# Epoch 212/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 97.3507 - accuracy: 0.0000e+00
# Epoch 213/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 95.9708 - accuracy: 0.0000e+00
# Epoch 214/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 94.6521 - accuracy: 0.0000e+00
# Epoch 215/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 94.6016 - accuracy: 0.0000e+00
# Epoch 216/1000
# 721/721 [==============================] - 0s 65us/sample - loss: 94.5690 - accuracy: 0.0000e+00
# Epoch 217/1000
# 721/721 [==============================] - 0s 62us/sample - loss: 93.4283 - accuracy: 0.0000e+00
# Epoch 218/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 98.2015 - accuracy: 0.0000e+00
# Epoch 219/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 101.5208 - accuracy: 0.0000e+00
# Epoch 220/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 98.2915 - accuracy: 0.0000e+00
# Epoch 221/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 102.4849 - accuracy: 0.0000e+00
# Epoch 222/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 100.5359 - accuracy: 0.0000e+00
# Epoch 223/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 98.0805 - accuracy: 0.0000e+00
# Epoch 224/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 96.8358 - accuracy: 0.0000e+00
# Epoch 225/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 94.5876 - accuracy: 0.0000e+00
# Epoch 226/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 93.3361 - accuracy: 0.0000e+00
# Epoch 227/1000
# 721/721 [==============================] - 0s 40us/sample - loss: 94.2649 - accuracy: 0.0000e+00
# Epoch 228/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 96.6186 - accuracy: 0.0000e+00
# Epoch 229/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 97.3780 - accuracy: 0.0000e+00
# Epoch 230/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 94.6107 - accuracy: 0.0000e+00
# Epoch 231/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 93.2398 - accuracy: 0.0000e+00
# Epoch 232/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 95.9765 - accuracy: 0.0000e+00
# Epoch 233/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 93.4733 - accuracy: 0.0000e+00
# Epoch 234/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 96.2427 - accuracy: 0.0000e+00
# Epoch 235/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 93.3564 - accuracy: 0.0000e+00
# Epoch 236/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 95.4011 - accuracy: 0.0000e+00
# Epoch 237/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 95.3640 - accuracy: 0.0000e+00
# Epoch 238/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 103.7041 - accuracy: 0.0000e+00
# Epoch 239/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 100.8054 - accuracy: 0.0000e+00
# Epoch 240/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 98.5242 - accuracy: 0.0000e+00
# Epoch 241/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 92.9210 - accuracy: 0.0000e+00
# Epoch 242/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 95.3110 - accuracy: 0.0000e+00
# Epoch 243/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 91.8460 - accuracy: 0.0000e+00
# Epoch 244/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 95.2220 - accuracy: 0.0000e+00
# Epoch 245/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 95.0082 - accuracy: 0.0000e+00
# Epoch 246/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 92.0114 - accuracy: 0.0000e+00
# Epoch 247/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 91.9624 - accuracy: 0.0000e+00
# Epoch 248/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 94.9975 - accuracy: 0.0000e+00
# Epoch 249/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 98.5681 - accuracy: 0.0000e+00
# Epoch 250/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 96.7718 - accuracy: 0.0000e+00
# Epoch 251/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 92.9209 - accuracy: 0.0000e+00
# Epoch 252/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 90.5893 - accuracy: 0.0000e+00
# Epoch 253/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 96.7304 - accuracy: 0.0000e+00
# Epoch 254/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 97.6965 - accuracy: 0.0000e+00
# Epoch 255/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 91.9599 - accuracy: 0.0000e+00
# Epoch 256/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 88.9878 - accuracy: 0.0000e+00
# Epoch 257/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 87.1769 - accuracy: 0.0000e+00
# Epoch 258/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 94.0444 - accuracy: 0.0000e+00
# Epoch 259/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 93.8135 - accuracy: 0.0000e+00
# Epoch 260/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 88.8977 - accuracy: 0.0000e+00
# Epoch 261/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 92.9824 - accuracy: 0.0000e+00
# Epoch 262/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 83.0730 - accuracy: 0.0000e+00
# Epoch 263/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 84.9477 - accuracy: 0.0000e+00
# Epoch 264/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 84.6579 - accuracy: 0.0000e+00
# Epoch 265/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 78.8569 - accuracy: 0.0000e+00
# Epoch 266/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 78.9477 - accuracy: 0.0000e+00
# Epoch 267/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 76.9771 - accuracy: 0.0000e+00
# Epoch 268/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 77.8543 - accuracy: 0.0000e+00
# Epoch 269/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 75.7586 - accuracy: 0.0000e+00
# Epoch 270/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 75.1869 - accuracy: 0.0000e+00
# Epoch 271/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 75.9437 - accuracy: 0.0000e+00
# Epoch 272/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 79.9785 - accuracy: 0.0000e+00
# Epoch 273/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 74.2506 - accuracy: 0.0000e+00
# Epoch 274/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 73.9371 - accuracy: 0.0000e+00
# Epoch 275/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 77.8521 - accuracy: 0.0000e+00
# Epoch 276/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 77.2486 - accuracy: 0.0000e+00
# Epoch 277/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 70.7817 - accuracy: 0.0000e+00
# Epoch 278/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 71.5792 - accuracy: 0.0000e+00
# Epoch 279/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 72.9314 - accuracy: 0.0000e+00
# Epoch 280/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 72.0777 - accuracy: 0.0000e+00
# Epoch 281/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 70.5837 - accuracy: 0.0000e+00
# Epoch 282/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 71.9008 - accuracy: 0.0000e+00
# Epoch 283/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 71.1304 - accuracy: 0.0000e+00
# Epoch 284/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 67.6976 - accuracy: 0.0000e+00
# Epoch 285/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 69.2835 - accuracy: 0.0000e+00
# Epoch 286/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 72.9627 - accuracy: 0.0000e+00
# Epoch 287/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 70.7699 - accuracy: 0.0000e+00
# Epoch 288/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 68.6341 - accuracy: 0.0000e+00
# Epoch 289/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 67.3141 - accuracy: 0.0000e+00
# Epoch 290/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 70.0738 - accuracy: 0.0000e+00
# Epoch 291/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 66.6815 - accuracy: 0.0000e+00
# Epoch 292/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 68.1563 - accuracy: 0.0000e+00
# Epoch 293/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 65.2126 - accuracy: 0.0000e+00
# Epoch 294/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 66.2200 - accuracy: 0.0000e+00
# Epoch 295/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 67.2500 - accuracy: 0.0000e+00
# Epoch 296/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 64.8173 - accuracy: 0.0000e+00
# Epoch 297/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 66.7828 - accuracy: 0.0000e+00
# Epoch 298/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 65.3739 - accuracy: 0.0000e+00
# Epoch 299/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 64.3024 - accuracy: 0.0000e+00
# Epoch 300/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 67.7802 - accuracy: 0.0000e+00
# Epoch 301/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 67.6833 - accuracy: 0.0000e+00
# Epoch 302/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 66.9611 - accuracy: 0.0000e+00
# Epoch 303/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 66.1886 - accuracy: 0.0000e+00
# Epoch 304/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 66.6313 - accuracy: 0.0000e+00
# Epoch 305/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 67.0450 - accuracy: 0.0000e+00
# Epoch 306/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 70.1921 - accuracy: 0.0000e+00
# Epoch 307/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 70.1027 - accuracy: 0.0000e+00
# Epoch 308/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 63.9625 - accuracy: 0.0000e+00
# Epoch 309/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 63.0738 - accuracy: 0.0000e+00
# Epoch 310/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 63.7846 - accuracy: 0.0000e+00
# Epoch 311/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 66.0179 - accuracy: 0.0000e+00
# Epoch 312/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 63.4630 - accuracy: 0.0000e+00
# Epoch 313/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 64.3652 - accuracy: 0.0000e+00
# Epoch 314/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 62.7310 - accuracy: 0.0000e+00
# Epoch 315/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 63.8323 - accuracy: 0.0000e+00
# Epoch 316/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 63.1922 - accuracy: 0.0000e+00
# Epoch 317/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 62.0440 - accuracy: 0.0000e+00
# Epoch 318/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 64.3360 - accuracy: 0.0000e+00
# Epoch 319/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 64.7380 - accuracy: 0.0000e+00
# Epoch 320/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 67.9140 - accuracy: 0.0000e+00
# Epoch 321/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 62.8461 - accuracy: 0.0000e+00
# Epoch 322/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 60.3382 - accuracy: 0.0000e+00
# Epoch 323/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 61.5239 - accuracy: 0.0000e+00
# Epoch 324/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 59.9694 - accuracy: 0.0000e+00
# Epoch 325/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 63.7169 - accuracy: 0.0000e+00
# Epoch 326/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 65.7587 - accuracy: 0.0000e+00
# Epoch 327/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 62.1251 - accuracy: 0.0000e+00
# Epoch 328/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 60.1399 - accuracy: 0.0000e+00
# Epoch 329/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 59.1173 - accuracy: 0.0000e+00
# Epoch 330/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 60.5557 - accuracy: 0.0000e+00
# Epoch 331/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 62.4357 - accuracy: 0.0000e+00
# Epoch 332/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 58.2669 - accuracy: 0.0000e+00
# Epoch 333/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 62.5819 - accuracy: 0.0000e+00
# Epoch 334/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 63.7087 - accuracy: 0.0000e+00
# Epoch 335/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 65.3412 - accuracy: 0.0000e+00
# Epoch 336/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 65.2567 - accuracy: 0.0000e+00
# Epoch 337/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 63.3366 - accuracy: 0.0000e+00
# Epoch 338/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 61.3833 - accuracy: 0.0000e+00
# Epoch 339/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 60.0520 - accuracy: 0.0000e+00
# Epoch 340/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 56.9826 - accuracy: 0.0000e+00
# Epoch 341/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 56.9410 - accuracy: 0.0000e+00
# Epoch 342/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 57.0259 - accuracy: 0.0000e+00
# Epoch 343/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 59.4273 - accuracy: 0.0000e+00
# Epoch 344/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 57.7477 - accuracy: 0.0000e+00
# Epoch 345/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 56.6966 - accuracy: 0.0000e+00
# Epoch 346/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 59.4958 - accuracy: 0.0000e+00
# Epoch 347/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 57.2619 - accuracy: 0.0000e+00
# Epoch 348/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 59.1123 - accuracy: 0.0000e+00
# Epoch 349/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 59.0175 - accuracy: 0.0000e+00
# Epoch 350/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 59.9697 - accuracy: 0.0000e+00
# Epoch 351/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 57.6565 - accuracy: 0.0000e+00
# Epoch 352/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 55.3851 - accuracy: 0.0000e+00
# Epoch 353/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 58.0038 - accuracy: 0.0000e+00
# Epoch 354/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 57.7035 - accuracy: 0.0000e+00
# Epoch 355/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 53.8773 - accuracy: 0.0000e+00
# Epoch 356/1000
# 721/721 [==============================] - 0s 57us/sample - loss: 54.2749 - accuracy: 0.0000e+00
# Epoch 357/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 54.9073 - accuracy: 0.0000e+00
# Epoch 358/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 56.8995 - accuracy: 0.0000e+00
# Epoch 359/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 52.8496 - accuracy: 0.0000e+00
# Epoch 360/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 57.4240 - accuracy: 0.0000e+00
# Epoch 361/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 54.6290 - accuracy: 0.0000e+00
# Epoch 362/1000
# 721/721 [==============================] - 0s 58us/sample - loss: 58.0226 - accuracy: 0.0000e+00
# Epoch 363/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 54.4394 - accuracy: 0.0000e+00
# Epoch 364/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 54.7218 - accuracy: 0.0000e+00
# Epoch 365/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 53.8273 - accuracy: 0.0000e+00
# Epoch 366/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 60.5928 - accuracy: 0.0000e+00
# Epoch 367/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 55.7050 - accuracy: 0.0000e+00
# Epoch 368/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 64.8018 - accuracy: 0.0000e+00
# Epoch 369/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 56.0833 - accuracy: 0.0000e+00
# Epoch 370/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 51.4859 - accuracy: 0.0000e+00
# Epoch 371/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 52.7739 - accuracy: 0.0000e+00
# Epoch 372/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 53.4281 - accuracy: 0.0000e+00
# Epoch 373/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 57.2968 - accuracy: 0.0000e+00
# Epoch 374/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 60.8740 - accuracy: 0.0000e+00
# Epoch 375/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 56.8362 - accuracy: 0.0000e+00
# Epoch 376/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 51.8668 - accuracy: 0.0000e+00
# Epoch 377/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 51.2747 - accuracy: 0.0000e+00
# Epoch 378/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 50.4493 - accuracy: 0.0000e+00
# Epoch 379/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 52.5846 - accuracy: 0.0000e+00
# Epoch 380/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 59.1645 - accuracy: 0.0000e+00
# Epoch 381/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 55.0863 - accuracy: 0.0000e+00
# Epoch 382/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 54.2574 - accuracy: 0.0000e+00
# Epoch 383/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 53.6152 - accuracy: 0.0000e+00
# Epoch 384/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 53.4738 - accuracy: 0.0000e+00
# Epoch 385/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 51.9561 - accuracy: 0.0000e+00
# Epoch 386/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 49.5689 - accuracy: 0.0000e+00
# Epoch 387/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 51.0253 - accuracy: 0.0000e+00
# Epoch 388/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 53.3182 - accuracy: 0.0000e+00
# Epoch 389/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 51.4468 - accuracy: 0.0000e+00
# Epoch 390/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 49.4802 - accuracy: 0.0000e+00
# Epoch 391/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 50.3931 - accuracy: 0.0000e+00
# Epoch 392/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 50.7310 - accuracy: 0.0000e+00
# Epoch 393/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 52.8883 - accuracy: 0.0000e+00
# Epoch 394/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 50.3854 - accuracy: 0.0000e+00
# Epoch 395/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 51.5336 - accuracy: 0.0000e+00
# Epoch 396/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 52.5806 - accuracy: 0.0000e+00
# Epoch 397/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 50.8759 - accuracy: 0.0000e+00
# Epoch 398/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 50.4808 - accuracy: 0.0000e+00
# Epoch 399/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 51.9077 - accuracy: 0.0000e+00
# Epoch 400/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 49.8143 - accuracy: 0.0000e+00
# Epoch 401/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 50.5844 - accuracy: 0.0000e+00
# Epoch 402/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 52.0733 - accuracy: 0.0000e+00
# Epoch 403/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 55.9160 - accuracy: 0.0000e+00
# Epoch 404/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 57.2266 - accuracy: 0.0000e+00
# Epoch 405/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 56.2233 - accuracy: 0.0000e+00
# Epoch 406/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 49.2735 - accuracy: 0.0000e+00
# Epoch 407/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 50.3931 - accuracy: 0.0000e+00
# Epoch 408/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 51.6756 - accuracy: 0.0000e+00
# Epoch 409/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 50.7045 - accuracy: 0.0000e+00
# Epoch 410/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 49.6175 - accuracy: 0.0000e+00
# Epoch 411/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 54.0779 - accuracy: 0.0000e+00
# Epoch 412/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 57.0149 - accuracy: 0.0000e+00
# Epoch 413/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 58.1078 - accuracy: 0.0000e+00
# Epoch 414/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 57.1218 - accuracy: 0.0000e+00
# Epoch 415/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 52.4829 - accuracy: 0.0000e+00
# Epoch 416/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 59.7922 - accuracy: 0.0000e+00
# Epoch 417/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 52.5777 - accuracy: 0.0000e+00
# Epoch 418/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 53.5584 - accuracy: 0.0000e+00
# Epoch 419/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 55.3174 - accuracy: 0.0000e+00
# Epoch 420/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 53.5482 - accuracy: 0.0000e+00
# Epoch 421/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 50.0239 - accuracy: 0.0000e+00
# Epoch 422/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 51.5907 - accuracy: 0.0000e+00
# Epoch 423/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 50.1415 - accuracy: 0.0000e+00
# Epoch 424/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 66.6613 - accuracy: 0.0000e+00
# Epoch 425/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 51.2932 - accuracy: 0.0000e+00
# Epoch 426/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 48.6047 - accuracy: 0.0000e+00
# Epoch 427/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 47.5880 - accuracy: 0.0000e+00
# ...
# Epoch 859/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 46.1775 - accuracy: 0.0000e+00
# Epoch 860/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 46.4849 - accuracy: 0.0000e+00
# Epoch 861/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 48.0744 - accuracy: 0.0000e+00
# Epoch 862/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 43.9078 - accuracy: 0.0000e+00
# Epoch 863/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 47.2329 - accuracy: 0.0000e+00
# Epoch 864/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 48.5536 - accuracy: 0.0000e+00
# Epoch 865/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 45.8358 - accuracy: 0.0000e+00
# Epoch 866/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 44.8867 - accuracy: 0.0000e+00
# Epoch 867/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 50.3246 - accuracy: 0.0000e+00
# Epoch 868/1000
# 721/721 [==============================] - 0s 61us/sample - loss: 45.6081 - accuracy: 0.0000e+00
# Epoch 869/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 47.0909 - accuracy: 0.0000e+00
# Epoch 870/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 53.6380 - accuracy: 0.0000e+00
# Epoch 871/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 46.0204 - accuracy: 0.0000e+00
# Epoch 872/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 44.4752 - accuracy: 0.0000e+00
# Epoch 873/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 48.6088 - accuracy: 0.0000e+00
# Epoch 874/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 47.3471 - accuracy: 0.0000e+00
# Epoch 875/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 45.4370 - accuracy: 0.0000e+00
# Epoch 876/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 45.4686 - accuracy: 0.0000e+00
# Epoch 877/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 46.2695 - accuracy: 0.0000e+00
# Epoch 878/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 46.3415 - accuracy: 0.0000e+00
# Epoch 879/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 46.4080 - accuracy: 0.0000e+00
# Epoch 880/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 47.5460 - accuracy: 0.0000e+00
# Epoch 881/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 45.3046 - accuracy: 0.0000e+00
# Epoch 882/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 44.9458 - accuracy: 0.0000e+00
# Epoch 883/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 47.8915 - accuracy: 0.0000e+00
# Epoch 884/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 46.9409 - accuracy: 0.0000e+00
# Epoch 885/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 48.3202 - accuracy: 0.0000e+00
# Epoch 886/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 46.8694 - accuracy: 0.0000e+00
# Epoch 887/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 44.5294 - accuracy: 0.0000e+00
# Epoch 888/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 45.4702 - accuracy: 0.0000e+00
# Epoch 889/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 45.0364 - accuracy: 0.0000e+00
# Epoch 890/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 51.3111 - accuracy: 0.0000e+00
# Epoch 891/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 45.6918 - accuracy: 0.0000e+00
# Epoch 892/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 45.3170 - accuracy: 0.0000e+00
# Epoch 893/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 44.6913 - accuracy: 0.0000e+00
# Epoch 894/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 48.6812 - accuracy: 0.0000e+00
# Epoch 895/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 48.2559 - accuracy: 0.0000e+00
# Epoch 896/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 45.7330 - accuracy: 0.0000e+00
# Epoch 897/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 50.9658 - accuracy: 0.0000e+00
# Epoch 898/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 49.1568 - accuracy: 0.0000e+00
# Epoch 899/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 48.4844 - accuracy: 0.0000e+00
# Epoch 900/1000
# 721/721 [==============================] - 0s 62us/sample - loss: 46.1235 - accuracy: 0.0000e+00
# Epoch 901/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 47.2027 - accuracy: 0.0000e+00
# Epoch 902/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 46.9361 - accuracy: 0.0000e+00
# Epoch 903/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 45.0256 - accuracy: 0.0000e+00
# Epoch 904/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 45.2869 - accuracy: 0.0000e+00
# Epoch 905/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 45.4198 - accuracy: 0.0000e+00
# Epoch 906/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 47.7525 - accuracy: 0.0000e+00
# Epoch 907/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 46.4676 - accuracy: 0.0000e+00
# Epoch 908/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 49.3327 - accuracy: 0.0000e+00
# Epoch 909/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 54.7692 - accuracy: 0.0000e+00
# Epoch 910/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 52.1260 - accuracy: 0.0000e+00
# Epoch 911/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 57.3045 - accuracy: 0.0000e+00
# Epoch 912/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 48.2089 - accuracy: 0.0000e+00
# Epoch 913/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 47.0079 - accuracy: 0.0000e+00
# Epoch 914/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 50.8075 - accuracy: 0.0000e+00
# Epoch 915/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 45.3956 - accuracy: 0.0000e+00
# Epoch 916/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 49.3715 - accuracy: 0.0000e+00
# Epoch 917/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 52.4200 - accuracy: 0.0000e+00
# Epoch 918/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 48.6273 - accuracy: 0.0000e+00
# Epoch 919/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 46.5259 - accuracy: 0.0000e+00
# Epoch 920/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 45.8225 - accuracy: 0.0000e+00
# Epoch 921/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 44.6139 - accuracy: 0.0000e+00
# Epoch 922/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 46.0050 - accuracy: 0.0000e+00
# Epoch 923/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 44.5551 - accuracy: 0.0000e+00
# Epoch 924/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 48.8161 - accuracy: 0.0000e+00
# Epoch 925/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 49.3442 - accuracy: 0.0000e+00
# Epoch 926/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 44.6563 - accuracy: 0.0000e+00
# Epoch 927/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 45.6457 - accuracy: 0.0000e+00
# Epoch 928/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 47.4303 - accuracy: 0.0000e+00
# Epoch 929/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 45.2344 - accuracy: 0.0000e+00
# Epoch 930/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 45.3332 - accuracy: 0.0000e+00
# Epoch 931/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 45.6608 - accuracy: 0.0000e+00
# Epoch 932/1000
# 721/721 [==============================] - 0s 55us/sample - loss: 45.8461 - accuracy: 0.0000e+00
# Epoch 933/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 50.4776 - accuracy: 0.0000e+00
# Epoch 934/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 49.5625 - accuracy: 0.0000e+00
# Epoch 935/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 48.7349 - accuracy: 0.0000e+00
# Epoch 936/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 45.7538 - accuracy: 0.0000e+00
# Epoch 937/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 49.6991 - accuracy: 0.0000e+00
# Epoch 938/1000
# 721/721 [==============================] - 0s 58us/sample - loss: 46.7907 - accuracy: 0.0000e+00
# Epoch 939/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 45.8911 - accuracy: 0.0000e+00
# Epoch 940/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 47.8534 - accuracy: 0.0000e+00
# Epoch 941/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 53.4770 - accuracy: 0.0000e+00
# Epoch 942/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 63.0801 - accuracy: 0.0000e+00
# Epoch 943/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 57.0830 - accuracy: 0.0000e+00
# Epoch 944/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 52.6683 - accuracy: 0.0000e+00
# Epoch 945/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 45.9216 - accuracy: 0.0000e+00
# Epoch 946/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 45.0023 - accuracy: 0.0000e+00
# Epoch 947/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 48.4048 - accuracy: 0.0000e+00
# Epoch 948/1000
# 721/721 [==============================] - 0s 64us/sample - loss: 45.8729 - accuracy: 0.0000e+00
# Epoch 949/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 53.2054 - accuracy: 0.0000e+00
# Epoch 950/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 47.1068 - accuracy: 0.0000e+00
# Epoch 951/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 44.5877 - accuracy: 0.0000e+00
# Epoch 952/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 44.5279 - accuracy: 0.0000e+00
# Epoch 953/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 46.0496 - accuracy: 0.0000e+00
# Epoch 954/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 44.7486 - accuracy: 0.0000e+00
# Epoch 955/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 50.0410 - accuracy: 0.0000e+00
# Epoch 956/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 44.2853 - accuracy: 0.0000e+00
# Epoch 957/1000
# 721/721 [==============================] - 0s 49us/sample - loss: 44.7841 - accuracy: 0.0000e+00
# Epoch 958/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 45.4610 - accuracy: 0.0000e+00
# Epoch 959/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 45.4191 - accuracy: 0.0000e+00
# Epoch 960/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 45.5378 - accuracy: 0.0000e+00
# Epoch 961/1000
# 721/721 [==============================] - 0s 50us/sample - loss: 51.1825 - accuracy: 0.0000e+00
# Epoch 962/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 46.7786 - accuracy: 0.0000e+00
# Epoch 963/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 52.0969 - accuracy: 0.0000e+00
# Epoch 964/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 47.6323 - accuracy: 0.0000e+00
# Epoch 965/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 49.9009 - accuracy: 0.0000e+00
# Epoch 966/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 48.6550 - accuracy: 0.0000e+00
# Epoch 967/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 45.7458 - accuracy: 0.0000e+00
# Epoch 968/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 50.7311 - accuracy: 0.0000e+00
# Epoch 969/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 45.7674 - accuracy: 0.0000e+00
# Epoch 970/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 48.5021 - accuracy: 0.0000e+00
# Epoch 971/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 49.6597 - accuracy: 0.0000e+00
# Epoch 972/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 49.9688 - accuracy: 0.0000e+00
# Epoch 973/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 48.4451 - accuracy: 0.0000e+00
# Epoch 974/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 47.3458 - accuracy: 0.0000e+00
# Epoch 975/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 49.1895 - accuracy: 0.0000e+00
# Epoch 976/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 49.6259 - accuracy: 0.0000e+00
# Epoch 977/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 53.3555 - accuracy: 0.0000e+00
# Epoch 978/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 46.5104 - accuracy: 0.0000e+00
# Epoch 979/1000
# 721/721 [==============================] - 0s 54us/sample - loss: 46.8536 - accuracy: 0.0000e+00
# Epoch 980/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 44.0933 - accuracy: 0.0000e+00
# Epoch 981/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 47.3211 - accuracy: 0.0000e+00
# Epoch 982/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 54.8079 - accuracy: 0.0000e+00
# Epoch 983/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 48.9223 - accuracy: 0.0000e+00
# Epoch 984/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 52.5666 - accuracy: 0.0000e+00
# Epoch 985/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 48.8923 - accuracy: 0.0000e+00
# Epoch 986/1000
# 721/721 [==============================] - 0s 53us/sample - loss: 44.6201 - accuracy: 0.0000e+00
# Epoch 987/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 46.9192 - accuracy: 0.0000e+00
# Epoch 988/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 45.1755 - accuracy: 0.0000e+00
# Epoch 989/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 43.9157 - accuracy: 0.0000e+00
# Epoch 990/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 44.6769 - accuracy: 0.0000e+00
# Epoch 991/1000
# 721/721 [==============================] - 0s 42us/sample - loss: 46.3165 - accuracy: 0.0000e+00
# Epoch 992/1000
# 721/721 [==============================] - 0s 43us/sample - loss: 45.0834 - accuracy: 0.0000e+00
# Epoch 993/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 44.7766 - accuracy: 0.0000e+00
# Epoch 994/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 44.4427 - accuracy: 0.0000e+00
# Epoch 995/1000
# 721/721 [==============================] - 0s 51us/sample - loss: 44.1037 - accuracy: 0.0000e+00
# Epoch 996/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 47.3305 - accuracy: 0.0000e+00
# Epoch 997/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 50.5254 - accuracy: 0.0000e+00
# Epoch 998/1000
# 721/721 [==============================] - 0s 46us/sample - loss: 45.2324 - accuracy: 0.0000e+00
# Epoch 999/1000
# 721/721 [==============================] - 0s 47us/sample - loss: 44.0497 - accuracy: 0.0000e+00
# Epoch 1000/1000
# 721/721 [==============================] - 0s 44us/sample - loss: 44.9163 - accuracy: 0.0000e+00

# %%
# Predicting the Test set results
y_pred = ann.predict(model.X_test)

# %%
y_pred.shape
# Out:
# (309, 1)

# %%
model.X_test.shape
# Out:
# (309, 8)

# %%
r2_score(model.y_test, y_pred)
# Out:
# 0.8133682454608886

# %%
rang = np.arange(len(y_pred))

# %%
plt.figure(figsize=(15,5))
plt.scatter(rang, y_pred)
plt.scatter(rang, model.y_test)
